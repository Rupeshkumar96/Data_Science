# %%
import requests as rp

# %%
response=rp.get('https://codingninjas.in/api/v3/courses')

# %%
## check the contectivity is ok or not
print(response.status_code)
# Out:
# 200

# %%
## Check the type of the data
print(type(response))
# Out:
# <class 'requests.models.Response'>

# %%
print(response.url)
# Out:
# https://www.codingninjas.com:443/api/v3/courses

# %%
print(response.encoding)
# Out:
# ISO-8859-1

# %%
print(response.text)
# Out:
# <!DOCTYPE html><html lang="en"><head>
#     <meta charset="utf-8">
#     <title>Coding Ninjas</title>
#
#     <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">
#     <meta name="title" content="Coding Ninjas">
#     <meta name="author" content="Coding Ninjas">
#     <meta property="og:title" content="Coding Ninjas">
#     <meta name="description" content="Best Programming Institute in India">
#     <meta property="og:description" content="Best Programming Institute in India">
#     <meta property="og:image" content="https://files.codingninjas.com/codingninjas-.webp">
#     <meta property="og:image:width" content="1800">
#     <meta property="og:image:height" content="942">
#
#     <link rel="preconnect" href="https://files.codingninjas.com">
#     <link rel="preconnect" href="https://files.codingninjas.in">
#
#     <script>
#       window.addEventListener('load', setWindowLoaded);
#
#       function getQueryParams() {
# ...

# %%
print(response.headers)
# Out:
# {'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Date': 'Sat, 02 May 2026 18:48:47 GMT', 'Cache-Control': 'must-revalidate, max-age=300', 'Last-Modified': 'Fri, 01 May 2026 11:12:31 GMT', 'Server': 'AmazonS3', 'Set-Cookie': 'geo_country=IN; Max-Age=2592000; Path=/; domain=.codingninjas.com; secure; SameSite=None', 'Content-Encoding': 'br', 'ETag': 'W/"ea0b263230e7116fc67e505896eade9b"', 'Vary': 'Accept-Encoding', 'Via': '1.1 537340030e8ccef978e104dbba16db16.cloudfront.net (CloudFront)', 'Alt-Svc': 'h3=":443"; ma=86400', 'Age': '20', 'X-Cache': 'Hit from cloudfront', 'X-Amz-Cf-Pop': 'DEL51-P5', 'X-Amz-Cf-Id': 'KoiWLHKKmXgBDl99Es4vMI_l1pdys8rwvZ8IXhsJHC5VusK9wCyoNQ=='}

# %%
data=response.headers['Content-Type']
print(data)
# Out:
# text/html

# %%
## Json code convert into python code.
import json
data='{"student":"mohit"}'
p_data=json.loads(data)
print(type(p_data))
# Out:
# <class 'dict'>

# %%
import pandas as pd
df=pd.DataFrame(data)

# %%
df
# Out:
#                     0
# 0        Content-Type
# 1   Transfer-Encoding
# 2          Connection
# 3                Date
# 4       Cache-Control
# 5       Last-Modified
# 6              Server
# 7          Set-Cookie
# 8    Content-Encoding
# 9                ETag
# 10               Vary
# 11                Via
# 12            Alt-Svc
# 13                Age
# 14            X-Cache
# 15       X-Amz-Cf-Pop
# 16        X-Amz-Cf-Id

# %%
## get data from  coding ninjas

# %%
import requests as rp
response=rp.get('https://codingninjas.in/api/v3/courses')
print(response.text)
# Out:
# <!DOCTYPE html><html lang="en"><head>
#     <meta charset="utf-8">
#     <title>Coding Ninjas</title>
#
#     <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">
#     <meta name="title" content="Coding Ninjas">
#     <meta name="author" content="Coding Ninjas">
#     <meta property="og:title" content="Coding Ninjas">
#     <meta name="description" content="Best Programming Institute in India">
#     <meta property="og:description" content="Best Programming Institute in India">
#     <meta property="og:image" content="https://files.codingninjas.com/codingninjas-.webp">
#     <meta property="og:image:width" content="1800">
#     <meta property="og:image:height" content="942">
#
#     <link rel="preconnect" href="https://files.codingninjas.com">
#     <link rel="preconnect" href="https://files.codingninjas.in">
#
#     <script>
#       window.addEventListener('load', setWindowLoaded);
#
#       function getQueryParams() {
# ...

# %%
import json
python_data=response.json
print(type(python_data))
all_course=python_data['data']['courses']
print(type(all_course))
# Out:
# <class 'method'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 python_data=response.json
#       3 print(type(python_data))
# ----> 4 all_course=python_data['data']['courses']
#       5 print(type(all_course))
#
# TypeError: 'method' object is not subscriptable
